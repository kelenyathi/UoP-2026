# %%
if True:
    print('true it is')
else:print('wrong')

# %%
print(type("Hello, World!"))
print(type(42))
print(type(3.145))
print(type(1j))
print(type(["egg", "bacon", "spam"]))
print(type(("egg", "bacon", "spam")))
print(type(range(6)))
print(type({"name" : "John", "age" : 80}))
print(type({"egg", "bacon", "spam"}))
print(type(True))
print(isinstance(3, int))

# %%
print('Hello, World!' == 'Hello, World!') #Equivalent value should use ==
print(2!=2)
print([1,2]<[1,2,3])
print(float(2)>=int(2))
print('a'<'A') #This is False as 'a' is Unicode 97 where 'A' is 65

# %%
number = int(input("8:"))  # input() function is fed to the int() function

if number == 10:
    print(f"{number} is equal to 10")  # String literals
else:
    print(f"{number} is not equal to 10")  # String literals
    
    # Note: formatting of the snippet
    # !! if-else statement can be nested !! This will be important for an in-class exersise.

# %%
number = int(input("Enter a number:"))  # input() function is fed to the int() function

if number == 10:
    print(f"{5} is between to 10")  # String literals
else:
    print(f"{number} is not equal to 10")  # String literals

# %%
cinema=int(input("what is your age"))
if cinema <= 5:
    print ("$0") 
if cinema >= 6 <= 12:
    print ("$5")
if cinema >= 13 <= 17:
   print ("$8")
if cinema >= 18 <= 59:
    print ("$12")
if cinema >= 60:
    print ("$0")
# Out:
# $5

# %%
grade=int(input("what is your grade"))
if grade >= 90:
    print ("A") 
elif grade >= 89 =<80 :
    print ("B")
elif grade >= 79 =< 70:
    print ("C")
elif grade >= 69 =< 60:
    print ("D")
else:
    print ("F")
# Out:
#   Cell In[9], line 4
#     elif grade >= 89 =< 80 :
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(
    diamonds, x="clarity", y="carat",
    color="b", order=clarity_ranking, width_method="linear",
)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

diamonds = sns.load_dataset("diamonds")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    diamonds,
    x="price", hue="cut",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500, 1000, 2000, 5000, 10000])
# Out:
# [<matplotlib.axis.XTick at 0x7c5b7baa2cf0>,
#  <matplotlib.axis.XTick at 0x7c5b7b88cfe0>,
#  <matplotlib.axis.XTick at 0x7c5b7baa04d0>,
#  <matplotlib.axis.XTick at 0x7c5b7b0c5520>,
#  <matplotlib.axis.XTick at 0x7c5b7b089490>]
