# %% [markdown]
# </> Markdown
# Portfolio
# This notebook has solutions to all exercises for the module
# Code has been written and tested step by step #

# %%
#Ask‍user‍to‍enter‍a‍number
num = int(input("Enter a number: "))

is_prime = True

if num <= 1:
    is_prime = False
else:
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break

if is_prime:
        print ("THIS IS A PRIME NUMBER")
else:
    print("THIS IS NOT A PRIME NUMBER")
# Out:
# THIS IS A PRIME NUMBER

# %% [markdown]
# #Exercise 2

# %%
n=int(input("How many Fibonacci numbers?"))

a, b = 0, 1

for i in range (n):
    print (a)
    a, b = b, a + b
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# #Exercise 3

# %%
for i in range (5, 0, -1):
    print("*" * i)

for i in range (2, 6):
    print ("*" * i)
# Out:
# *****
# ****
# ***
# **
# *
# **
# ***
# ****
# *****

# %% [markdown]
# Exercise 4

# %%
def reverse_string ():
    text=input("Enter a string:")
    print("Reversed:, text[::-1]")

reverse_string ()
# Out:
# Reversed:, text[::-1]

# %% [markdown]
# Exercise 5

# %%
def find_extremes(data):
    #this will return the smallest and largest numbers as a pair 
    return min(data), max(data)

my_nums = [10,40,1,90,32]
low, high = find_extremes(my_nums)

print(f"Min value is: {low}")
print(f"Max value is: {high}")
# Out:
# Min value is: 1
# Max value is: 90

# %% [markdown]
# Exercise 6

# %%
import random

secret = random.randint(1,10)
while True:
    guess = int(input("Guess a number (1-10): "))
if guess > secret:
    print ("Too high. Try Again")
elif guess < secret:
    print("Too low. Try again.")
else:
    print ("correct. you win!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       3 secret = random.randint(1,10)
#       4 while True:
# ----> 5     guess = int(input("Guess a number (1-10): "))
#       6 if guess > secret:
#       7     print ("Too high. Try Again")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# Exercise 7

# %%
while True:
    password = input ("enter password:")

    if password == "password":
        print("access granted")
        break
    else:
        print("incorrect password.  try again")
# Out:
# incorrect password.  try again
# incorrect password.  try again
# access granted

# %% [markdown]
# Exercise 8

# %%
import math 
def series (x,N):
    total=0

    for i in range (1, N +1):
        term=(x*(5**i)**2)/(i+math.factorial(i+1))
        total +=term

    return total

x = int(input("Enter x:"))
N = int(input("enter N:"))

print("Result:", SERIES (x,N))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 11
#       7         total +=term
#       9     return total
# ---> 11 x = int(input("Enter x:"))
#      12 N = int(input("enter N:"))
#      14 print("Result:", SERIES (x,N))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# Exercise 9

# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL import Image

img= Image.open ("your_image.jpg")
img_array = np.array (img)

horizontal = np.fliplr(img_array)
vetical = np.flipud (img_array)

plt.imshow (horizontal)
plt.tile ("Horizontal Reflection")
plt.show()

plt.imshow(vertical)
plt.title("Vetical Reflection")
plt.show()
# Out:
#   Cell In[5], line 3
#     import PIL import Image
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Exericse 10

# %%
import numpy as np
temps = np.array([22,24,19,21,23,25,26,27,24,23,30,22,21,29,20,22,21,29,28,22,23,24,26,28,30,27,25,26,24,22,21,20,19,23])
print ("Min:", temps.min())
print ("Max:", temps.max())
print ("Average:", temps.mean())

fahrenheit = (temps * 9/5) + 32

print("above 25:", temps [temps>25])
print("below 20 count:", len(temps[temps<20]))

print ("sorted:", np.sort(temps))
print ("reshaped:\n", temps.reshape(5,6))
# Out:
# Min: 19
# Max: 30
# Average: 24.0
# above 25: [26 27 30 29 29 28 26 28 30 27 26]
# below 20 count: 2
# sorted: [19 19 20 20 21 21 21 21 22 22 22 22 22 23 23 23 23 24 24 24 24 25 25 26
#  26 26 27 27 28 28 29 29 30 30]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 13
#      10 print("below 20 count:", len(temps[temps<20]))
#      12 print ("sorted:", np.sort(temps))
# ---> 13 print ("reshaped:\n", temps.reshape(5,6))
#
# ValueError: cannot reshape array of size 34 into shape (5,6)

# %% [markdown]
# Exercise 11

# %%
import pandas as pd
import numpy as np 
df=pd.DataFrame(
    np.random.randn(5,4),
    columns=["A", "B", "C","D"],
    index=["Row1", "Row2", "Row3", "Row4", "Row5"]
)

print(df)
print(df.shape)
print(df.describe())
# Out:
#              A         B         C         D
# Row1 -1.995961 -1.695906 -0.112097 -1.099332
# Row2 -0.635375  1.525792 -0.387808  1.193883
# Row3  0.331732 -0.374313 -0.994616 -0.215841
# Row4  0.540393 -0.140368  0.368171  0.182616
# Row5  0.291338  1.835603  0.226599 -0.222169
# (5, 4)
#               A         B         C         D
# count  5.000000  5.000000  5.000000  5.000000
# mean  -0.293574  0.230162 -0.179950 -0.032169
# std    1.053990  1.455036  0.542496  0.830363
# min   -1.995961 -1.695906 -0.994616 -1.099332
# 25%   -0.635375 -0.374313 -0.387808 -0.222169
# 50%    0.291338 -0.140368 -0.112097 -0.215841
# 75%    0.331732  1.525792  0.226599  0.182616
# max    0.540393  1.835603  0.368171  1.193883

# %% [markdown]
# Exercise 12

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")

iris.plot (kind='box')
plt.title("Iris Boxplot")
plt.show()

# %% [markdown]
# Exercise 13

# %%
import plotly.express as px
import seaborn as sns
tips=sns.load_dataset("tips")
fig=px.sunburst(tips, path=['sex', 'day', 'time'], values='tip')
fig.show
# Out:
# <bound method BaseFigure.show of Figure({
#     'data': [{'branchvalues': 'total',
#               'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'hovertemplate': 'labels=%{label}<br>tip=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>',
#               'ids': array(['Female/Sun/Dinner', 'Male/Sun/Dinner', 'Male/Sat/Dinner',
#                             'Female/Sat/Dinner', 'Male/Thur/Lunch', 'Female/Thur/Lunch',
#                             'Male/Fri/Dinner', 'Female/Fri/Dinner', 'Male/Fri/Lunch',
#                             'Female/Fri/Lunch', 'Female/Thur/Dinner', 'Female/Sun', 'Male/Sun',
#                             'Male/Sat', 'Female/Sat', 'Male/Thur', 'Female/Thur', 'Male/Fri',
#                             'Female/Fri', 'Female', 'Male'], dtype=object),
#               'labels': array(['Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Lunch', 'Dinner',
# ...

# %% [markdown]
# Exercise 14

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X=tips[['total bill']]
y=tips['tip']

model=LinearRegression()
model.fit(X,y)

prediction = model.predict([[50]])

print ("Predicted tip for £50 bill:", prediction[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       1 from sklearn.linear_model import LinearRegression
#       2 import numpy as np
# ----> 4 X=tips[['total bill']]
#       5 y=tips['tip']
#       7 model=LinearRegression()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %% [markdown]
# Exercise 15

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

titanic = sns.load_dataset("titanic")
titanic = titanic [['survived', 'sex', 'sibsp', 'parch', 'embarked']].dropna()

X=titanic.drop("survived", axis=1)
y=titanic["survived"]

categorical = ['sex','embarked']

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), categorical)
    ]
    remainder='passthrough'
)

X_processed = preprocessor.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2)

model=DecisionTreeClassifier()
model.fit(X_train, y_train)

accuracy = model.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
#   Cell In[19], line 16
#     transformers=,[
#     ^
# SyntaxError: expected argument value expression
